# %% [markdown]
# # 🎬 YouTube Comment Moderator AI
#
# ## Tone Classification & Summary Workflow
#
# ---
#
# ### 🚦 Moderation Flow
#
# 1️⃣ **User enters YouTube link**
#
# 2️⃣ **System fetches video comments**
#
# 3️⃣ **AI classifies comments**
#    - Toxicity
#    - Spam
#    - Hate
#    - Positive
#    - Neutral
#
# 4️⃣ **AI summarizes overall sentiment & issues**
#    - Highlights dominant tones
#    - Flags problematic trends
#    - Provides actionable insights
#
# 5️⃣ **Show moderation report**
#    - Visual summary of tone distribution
#    - Key findings & recommendations
#
# ---
#
# > **Example Output:**
# >
# > - **Tone Distribution:** ![Pie Chart Icon](https://img.icons8.com/color/48/000000/pie-chart.png)
# > - **Summary:** "Most comments are positive, but 12% show signs of toxicity. Spam detected in 8%."
# > - **Recommendations:** "Consider moderating toxic and spam comments. Overall sentiment is positive."
#
# ---
#
# ✨ Use this workflow to generate other cells for each step, making your notebook interactive and visually appealing!

# %% [markdown]
# ---
#
# ## STEP 1: Import Required Libraries
#
# Below are the libraries needed for the YouTube Comment Moderator AI, as listed in `requirements.txt`:
#
# - **google-api-python-client**: For accessing YouTube API and fetching comments
# - **pandas**: For data manipulation and analysis
# - **nltk**: For natural language processing and tone classification
# - **scikit-learn**: For machine learning models and sentiment analysis
# - **ollama**: For advanced AI and LLM integration
#
# > **Next:** Add a code cell to import these libraries and check their installation.

# %%
# Import required libraries for YouTube Comment Moderator AI
import os
from dotenv import load_dotenv
from openai import OpenAI
from googleapiclient.discovery import build
import pandas as pd
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
import ollama

# %%
video_url = "https://www.youtube.com/watch?v=hhrE_SytfyY"  # Example video URL

# %% [markdown]
# ##  STEP 2: Extract Video ID from URL

# %%
import re
def get_video_id(video_url):
    pattern = r"(?:v=|\/)([0-9A-Za-z_-]{11}).*"
    match = re.search(pattern, video_url)
    return match.group(1) if match else None

video_id = get_video_id(video_url)
video_id
# Out:
# 'hhrE_SytfyY'

# %% [markdown]
# ##  STEP 2: Fetch Comments from YouTube with your youtube API keys

# %%
load_dotenv(override=True)

youtube_api_key = os.getenv("YOUTUBE_API_KEY")
openrouter_api_key = os.getenv("OPEN_ROUTER_API_KEY")

if not youtube_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not youtube_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")

if not openrouter_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not openrouter_api_key.startswith("sk-or-v1-"):
    print("An Open Router API key was found, but it doesn't start sk-or-v1-")
else:
    print("An Open Router API key found and looks good so far!")
# Out:
# API key found and looks good so far!
# An Open Router API key found and looks good so far!

# %%
from googleapiclient.discovery import build

# Build the YouTube API client using the API key
youtube = build('youtube', 'v3', developerKey=youtube_api_key)

def get_all_comments(video_id):
    """
    Fetch all comments from a YouTube video using the YouTube Data API v3.
    Handles pagination to ensure all comments are retrieved.
    Args:
        video_id (str): The ID of the YouTube video.
    Returns:
        list: A list of comment strings.
    """
    comments = []
    # Create the initial API request for comment threads
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum allowed per page
        textFormat="plainText"
    )
    while request:
        # Execute the API request
        response = request.execute()
        # Loop through each comment in the response
        for item in response["items"]:
            comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
            comments.append(comment)
        # Get the next page of results, if any
        request = youtube.commentThreads().list_next(request, response)
    return comments

# Fetch all comments for the given video_id
comments = get_all_comments(video_id)
# Display the first 5 comments as a sample
comments[:5]
# Out:
# ['Drops on Wike’s office, he was there to tell them do the work I paid you for',
#  'They voted during coffew.',
#  'We are really tired of the wicked politicians leaders in Nigeria',
#  "Guys, let opposition parties gather the information of everything that happened and make a court case against all those who were responsible for rigging the FCT election; also bring the matter under the attention of the international community such as UN and AU; Nigerians should take a decision that unless the the electoral reform Act is fixed as per the people's wish no election will take place in 2027.",
#  'And Nigerian boasting of success. It hurts when you see the suffering of the people and the Politicians dont care']

# %% [markdown]
# ##  STEP 3: Classify Comments using Ollama

# %%
openai = OpenAI(
    api_key=openrouter_api_key,
    base_url="https://openrouter.ai/api/v1"
)

def classify_comment(comment):
    user_prompt = f"""
    Classify this YouTube comment into one category:

    Categories:
    - Positive
    - Neutral
    - Toxic
    - Spam
    - Hate Speech

    Comment: {comment}

    Return only the category name.
    """

    response = openai.chat.completions.create(
        model="openai/gpt-4o-mini",   # fast & cheap
        messages=[{"role": "user", "content": user_prompt}],
        temperature=0
    )

    # Fix: Access the content from the correct attribute
    return response.choices[0].message.content

# test
classify_comment("This video is amazing!")
# Out:
# 'Positive'

# %% [markdown]
# ## Step 4: Classify All Comments

# %%
results = []

for comment in comments:
    label = classify_comment(comment)
    results.append((comment, label))

results[:5]
# Out:
# [('Drops on Wike’s office, he was there to tell them do the work I paid you for',
#   'Neutral'),
#  ('They voted during coffew.', 'Neutral'),
#  ('We are really tired of the wicked politicians leaders in Nigeria', 'Toxic'),
#  ("Guys, let opposition parties gather the information of everything that happened and make a court case against all those who were responsible for rigging the FCT election; also bring the matter under the attention of the international community such as UN and AU; Nigerians should take a decision that unless the the electoral reform Act is fixed as per the people's wish no election will take place in 2027.",
#   'Neutral'),
#  ('And Nigerian boasting of success. It hurts when you see the suffering of the people and the Politicians dont care',
#   'Neutral')]

# %% [markdown]
# ## Step 5: Convert to DataFrame

# %%
import pandas as pd

df = pd.DataFrame(results, columns=["Comment", "Category"])
df.head()
# Out:
#                                              Comment Category
# 0  Drops on Wike’s office, he was there to tell t...  Neutral
# 1                          They voted during coffew.  Neutral
# 2  We are really tired of the wicked politicians ...    Toxic
# 3  Guys, let opposition parties gather the inform...  Neutral
# 4  And Nigerian boasting of success. It hurts whe...  Neutral

# %% [markdown]
# ## Step 6: Moderation Summary

# %%
summary_counts = df["Category"].value_counts()
summary_counts
# Out:
# Category
# Neutral     12
# Toxic       11
# Positive     1
# Name: count, dtype: int64

# %% [markdown]
# ## Step 7: AI Summary of Moderation

# %%
def summarize_results(summary):
    user_prompt = f"""
    Summarize the moderation results:

    {summary.to_dict()}

    Explain the overall sentiment and moderation concerns.
    """

    response = openai.chat.completions.create(
        model="openai/gpt-4o-mini",   # fast & cheap
        messages=[{"role": "user", "content": user_prompt}],
        temperature=0
    )

    return response.choices[0].message.content

summarize_results(summary_counts)
# Out:
# 'The moderation results indicate a total of 24 comments, categorized as follows: 12 comments are classified as Neutral, 11 as Toxic, and only 1 as Positive. \n\nOverall, the sentiment appears to be predominantly negative due to the high number of Toxic comments, which outnumber the Positive ones significantly. The presence of 11 Toxic comments suggests that there are considerable moderation concerns, as these comments may contain harmful, offensive, or inappropriate content. \n\nThe relatively low count of Positive comments indicates a lack of constructive or uplifting interactions within the dataset. The high Neutral count suggests that many comments may not express strong feelings either way, but the overwhelming Toxicity raises red flags about the overall environment and the need for effective moderation to address the negative interactions.'
